# %% [markdown]
# <a href="https://colab.research.google.com/github/VbsmRobotic/Image-processing-Tasks/blob/main/ImageProcessing_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import os

# !pip install -q gdown
import gdown

# url is the Google Drive file ID
file_id = '1LYXVjJN_XXQv9pJvPwSzG_rjw4pzVtqY'
output = 'img_1.png'

# Use the 'id' parameter with the file ID instead of the 'url' parameter
# Ensure the Google Drive file permissions are set to 'Anyone with the link'
gdown.download(id=file_id, output=output, quiet=False)

# Read the downloaded image
img = cv.imread(output, cv.IMREAD_COLOR_RGB)
# RGB

# BGR

# cv.imshow('image', img)
# cv.waitKey(0)
# cv.destroyAllWindows()

plt.imshow(img, cmap='gray', interpolation='bicubic')
#plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.plot([200,300,400],[100,200,300],'c', linewidth=5)
plt.show()


cv.imwrite('img_2.png', img)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LYXVjJN_XXQv9pJvPwSzG_rjw4pzVtqY
# To: /content/img_1.png
# 100%|██████████| 476k/476k [00:00<00:00, 96.2MB/s]
# True
